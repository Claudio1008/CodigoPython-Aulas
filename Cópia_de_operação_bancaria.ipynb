# %% [markdown]
# <a href="https://colab.research.google.com/github/Claudio1008/CodigoPython-Aulas/blob/main/C%C3%B3pia_de_opera%C3%A7%C3%A3o_bancaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

numero_secreto = random.randint(1, 10)
print("JOGO: Advinhe o numero")
while True:
  try:
    chute = int(input("Digite um numero entre 1 e 10 "))
    if chute == numero_secreto:
      print("Parabens voce acertou")
      break
    else:
      print("Numero errado tente novamente")
  except ValueError:
    print("Digite um numero valido")

# %%
saldo = 1000

while True:
   print("MENU")
   print("1 - SALDO")
   print("2 - DEPOSITO")
   print("3 - SACAR")
   print("4 - SAIR")
   try:
       selecionarAção = int(input("DIGITE O NUMERO REFERENTE A AÇÃO: "))

       if selecionarAção == 1:
           print(f"O SEU SALDO É {saldo}")

       elif selecionarAção == 2:
           valor = float(input("DIGITE O VALOR: "))
           saldo = saldo + valor
           print(f"O SEU SALDO É {saldo}")

       elif selecionarAção == 3:
           valor = float(input("DIGITE O VALOR: "))
           if valor <= saldo:
               saldo = saldo - valor
               print(f"O SEU SALDO É {saldo}")
           else:
               print("SALDO INSUFICIENTE")

       elif selecionarAção == 4:
           print("SAINDO")
           break
       else:
           print("DIGITE UMA AÇÃO VALIDA")

   except ValueError:
       print("Digite um numero valido")
   finally:
    print("OPERAÇÃO FINALIZADA")
